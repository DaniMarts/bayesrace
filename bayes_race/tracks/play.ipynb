# %%
from bayes_race.tracks import Rectangular
from bayes_race.raceline import randomTrajectory
import matplotlib.pyplot as plt

rec = Rectangular(50, 100, 5)

fig = rec.plot(plot_centre=True)

# %%
from bayes_race.tracks import ETHZ

ethz = ETHZ()

ethz.plot()

# %%
from bayes_race.tracks import UCB

ucb = UCB()

ucb.plot()
